# %%
import pandas as pd

# %%
df = pd.read_csv('./data/raw/GEDEvent_v25_1.csv')

print(df.shape)
print(df.dtypes)
print(df.memory_usage())
print(df.columns)
df.head()
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_34260\3496126250.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/raw/GEDEvent_v25_1.csv')
# (385918, 49)
# id                     int64
# relid                 object
# year                   int64
# active_year             bool
# code_status           object
# type_of_violence       int64
# conflict_dset_id       int64
# conflict_new_id        int64
# conflict_name         object
# dyad_dset_id           int64
# dyad_new_id            int64
# dyad_name             object
# side_a_dset_id         int64
# side_a_new_id          int64
# side_a                object
# side_b_dset_id         int64
# side_b_new_id          int64
# side_b                object
# number_of_sources      int64
# source_article        object
# source_office         object
# source_date           object
# source_headline       object
# source_original       object
# ...

# %%
df['type_of_violence'].values
# Out:
# array([1, 1, 1, ..., 3, 3, 3], shape=(385918,))

# %%
columns = ['id','year','date_start','date_end','type_of_violence','side_a','side_b','best','low','high', 'where_description']

df_important = df[columns]
print(df_important.dtypes)
print(df_important.isna().sum())
df['where_prec'].isna().sum()
# Out:
# id                    int64
# year                  int64
# date_start           object
# date_end             object
# type_of_violence      int64
# side_a               object
# side_b               object
# best                  int64
# low                   int64
# high                  int64
# where_description    object
# dtype: object
# id                       0
# year                     0
# date_start               0
# date_end                 0
# type_of_violence         0
# side_a                   0
# side_b                   0
# best                     0
# low                      0
# high                     0
# where_description    10243
# dtype: int64
# np.int64(0)

# %% [markdown]
# Practically no missing values (where_description) is only plain text but we have other ways to know the location of the event
#
# ### Summary
#
# Basically, each line represents a coded violent event, which may or may not be a military engagement described broadly. The column year or date_start may be used as a temporal indicator safely (no NA, specific).
#
# Both deaths_a and deaths_b can be used to assess the number of casualties of the event, since they do not have missing values. However, best, high and low should be studies with attention. For precaution purposes, only one of them should be used to describe the total number of death of a violent event. Here, we will use best. Furthermore, death_a + death_b should not be compared with best/high/low. They will not be used in a first time

# %%
# Out:
# np.int64(0)
